# %%
import pandas as pd
import altair as alt
import

# %%
from nba_api.stats.endpoints import commonplayerinfo

# %%
rb_data = pd.read_csv("C:/Users/mogde/Desktop/Git Repositories/BasketballProject/rb_data.csv")
rb_data = rb_data[["game", "team", "ORB", "DRB", "TRB", "sum_rb", "player"]]
andre_data = rb_data[rb_data["player"] == "Andre Drummond"]

# %%
alt.Chart(rb_data).mark_line().encode(
    x=alt.X("game:Q", axis=alt.Axis(title="Games Played")),
    y=alt.X("sum_rb:Q", axis=alt.Axis(title="Total Rebounds")),
    color="player:N")
# Out:
# alt.Chart(...)
